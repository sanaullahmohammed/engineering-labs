# %%
def aStar(start, end):
    open_set = set(start)
    closed_set = set()
    g = dict()
    parents = dict()
    g[start] = 0
    parents[start] = start
    
    while len(open_set) > 0:
        n = None
        
        for v in open_set:
            if n==None or g[v]+h[v] < g[n]+h[n]:
                n = v
        
        if n == None:
            print("Path not found")
            return
        
        if n == end:
            PATH = list()
            while parents[n] != n:
                PATH.append(n)
                n = parents[n]
            PATH.append(n)
            PATH.reverse()
            print(PATH)
            return
        
        if n != end or Graph[n] != None:
            for m,wt in Graph.get(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    parents[m] = n
                    g[m] = g[n]+wt
                elif g[m] > g[n]+wt:
                    g[m] = g[n]+wt
                    parents[m] = n
                    if m in closed_set:
                        open_set.add(m)
                        closed_set.remove(m)
            open_set.remove(n)
            closed_set.add(n)
    print("Path not found")
    return

# %%
Graph= {
    'A': [('B', 2), ('E', 3)],
    'B': [('C', 1), ('G', 9)],
    'C': None,
    'E': [('D', 6)],
    'D': [('G', 1)],
}

# %%
h = {
    'A': 11,
    'B': 6,
    'C': 99,
    'D': 1,
    'E': 7,
    'G': 0,
}

# %%
aStar('A','G')
# Out:
# ['A', 'E', 'D', 'G']
